# %% [markdown]
# # Outliere Removal using Z-score

# %% [markdown]
# Outliers can significantly impact the performance of certain algorithms, particularly those that are sensitive to variations in data. Here are some types of algorithms that are generally more affected by outliers:

# %% [raw]
# 1. Linear Regression
# 2. K-Means Clustering
# 3. K-Nearest Neighbors (KNN)
# 4. Principal Component Analysis (PCA)
# 5. Support Vector Machines (SVM)
# 6. Naive Bayes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df.shape
# Out:
# (1000, 3)

# %%
plt.figure(figsize=(16,5))

plt.subplot(1,2,1)
sns.distplot(df.cgpa)

plt.subplot(1,2,2)
sns.distplot(df.placement_exam_marks)
plt.show()

# %% [markdown]
# If plot look like normal distribution then we use 'Z-score and below methods'
# If plot look like skewness then we use 'IQR' method
#
# In uppor two plots, cpga is normal & place_exam_marks is skew

# %%
df.placement_exam_marks.skew()
# Out:
# 0.8356419499466834

# %%
print("Mean value of cgpa",df['cgpa'].mean())
print("Std value of cgpa",df['cgpa'].std())
print("Min value of cgpa",df['cgpa'].min())
print("Max value of cgpa",df['cgpa'].max())
# Out:
# Mean value of cgpa 6.96124
# Std value of cgpa 0.6158978751323894
# Min value of cgpa 4.89
# Max value of cgpa 9.12

# %%
print('Highest Allowed: ', df['cgpa'].mean()+3*df['cgpa'].std())
print('Lowest Allowed: ', df['cgpa'].mean()-3*df['cgpa'].std())
# Out:
# Highest Allowed:  8.808933625397168
# Lowest Allowed:  5.113546374602832

# %%
#Finding Outliers

df[(df.cgpa > 8.80)|(df.cgpa<5.11)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %% [markdown]
# # Trimming

# %%
new_df = df[(df.cgpa < 8.80) & (df.cgpa > 5.11)]
new_df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
new_df.shape #now we can work with this dataset
# Out:
# (995, 3)

# %% [markdown]
# # Approach 2 (Calculating Z-Score)

# %%
df['cgpa_zscore'] = (df.cgpa - df.cgpa.mean()) / df.cgpa.std()

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed  cgpa_zscore
# 0  7.19                  26.0       1     0.371425
# 1  7.46                  38.0       1     0.809810
# 2  7.54                  40.0       1     0.939701
# 3  6.42                   8.0       1    -0.878782
# 4  7.23                  17.0       0     0.436371

# %%
df.cgpa_zscore.describe()
# Out:
# count    1.000000e+03
# mean    -1.474376e-16
# std      1.000000e+00
# min     -3.362960e+00
# 25%     -6.677081e-01
# 50%     -2.013321e-03
# 75%      6.636815e-01
# max      3.505062e+00
# Name: cgpa_zscore, dtype: float64

# %%
df[df['cgpa_zscore'] > 3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 995  8.87                  44.0       1     3.099150
# 996  9.12                  65.0       1     3.505062

# %%
df[df['cgpa_zscore'] < -3]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                  44.0       1    -3.314251
# 997  4.89                  34.0       0    -3.362960
# 999  4.90                  10.0       1    -3.346724

# %%
df[(df['cgpa_zscore'] > 3) | (df['cgpa_zscore'] < -3)]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                  44.0       1    -3.314251
# 995  8.87                  44.0       1     3.099150
# 996  9.12                  65.0       1     3.505062
# 997  4.89                  34.0       0    -3.362960
# 999  4.90                  10.0       1    -3.346724

# %%
# Trimming 
new_df = df[(df['cgpa_zscore'] < 3) & (df['cgpa_zscore'] > -3)]

# %%
new_df
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.19                  26.0       1     0.371425
# 1    7.46                  38.0       1     0.809810
# 2    7.54                  40.0       1     0.939701
# 3    6.42                   8.0       1    -0.878782
# 4    7.23                  17.0       0     0.436371
# ..    ...                   ...     ...          ...
# 991  7.04                  57.0       0     0.127878
# 992  6.26                  12.0       0    -1.138565
# 993  6.73                  21.0       1    -0.375452
# 994  6.48                  63.0       0    -0.781363
# 998  8.62                  46.0       1     2.693239
#
# [995 rows x 4 columns]

# %% [markdown]
# # Capping

# %% [raw]
# #capping is the best cause it's don't lose any rows as it lose before method

# %%
upper_limit = df['cgpa'].mean() + 3*df['cgpa'].std()
lower_limit = df['cgpa'].mean() - 3*df['cgpa'].std()

# %%
upper_limit, lower_limit
# Out:
# (8.808933625397168, 5.113546374602832)

# %% [raw]
# # The below condition is work like (If, else if , else)

# %%
df['cgpa'] = np.where( df.cgpa > upper_limit,
                     upper_limit,
                     
                     np.where(
                     df.cgpa < lower_limit,
                     lower_limit,
                     df.cgpa))

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.cgpa.describe()
# Out:
# count    1000.000000
# mean        6.961499
# std         0.612688
# min         5.113546
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         8.808934
# Name: cgpa, dtype: float64

# %% [markdown]
# # IQR method

# %%
sns.distplot(df.placement_exam_marks)
# Out:
# <Axes: xlabel='placement_exam_marks', ylabel='Density'>

# %%
df.placement_exam_marks.describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.boxplot(df.placement_exam_marks)
# Out:
# <Axes: >

# %%
# Finding the IQR
percentile25 = df['placement_exam_marks'].quantile(0.25)
percentile75 = df['placement_exam_marks'].quantile(0.75)

# %%
iqr = percentile75 - percentile25
iqr
# Out:
# 27.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
upper_limit, lower_limit
# Out:
# (84.5, -23.5)

# %%
#finding outliers

# %%
df[df.placement_exam_marks > upper_limit]
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 9    7.75                  94.0       1     1.280667
# 40   6.60                  86.0       1    -0.586526
# 61   7.51                  86.0       0     0.890992
# 134  6.33                  93.0       0    -1.024910
# 162  7.80                  90.0       0     1.361849
# 283  7.09                  87.0       0     0.209061
# 290  8.38                  87.0       0     2.303564
# 311  6.97                  87.0       1     0.014223
# 324  6.64                  90.0       0    -0.521580
# 630  6.56                  96.0       1    -0.651472
# 685  6.05                  87.0       1    -1.479531
# 730  6.14                  90.0       1    -1.333403
# 771  7.31                  86.0       1     0.566263
# 846  6.99                  97.0       0     0.046696
# 917  5.95                 100.0       0    -1.641896

# %%
df[df.placement_exam_marks < lower_limit]
# Out:
# Empty DataFrame
# Columns: [cgpa, placement_exam_marks, placed, cgpa_zscore]
# Index: []

# %%
#trimming

# %%
new_df = df[df['placement_exam_marks'] < upper_limit]
new_df
# Out:
#          cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.190000                  26.0       1     0.371425
# 1    7.460000                  38.0       1     0.809810
# 2    7.540000                  40.0       1     0.939701
# 3    6.420000                   8.0       1    -0.878782
# 4    7.230000                  17.0       0     0.436371
# ..        ...                   ...     ...          ...
# 995  8.808934                  44.0       1     3.099150
# 996  8.808934                  65.0       1     3.505062
# 997  5.113546                  34.0       0    -3.362960
# 998  8.620000                  46.0       1     2.693239
# 999  5.113546                  10.0       1    -3.346724
#
# [985 rows x 4 columns]

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(new_df['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(new_df['placement_exam_marks'])

plt.show()

# %%
#Capping

# %%
new_df_cap = df.copy()

new_df_cap['placement_exam_marks'] = np.where(
    new_df_cap['placement_exam_marks'] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap['placement_exam_marks'] < lower_limit,
        lower_limit,
        new_df_cap['placement_exam_marks']
    )
)

# %%
new_df_cap
# Out:
#          cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.190000                  26.0       1     0.371425
# 1    7.460000                  38.0       1     0.809810
# 2    7.540000                  40.0       1     0.939701
# 3    6.420000                   8.0       1    -0.878782
# 4    7.230000                  17.0       0     0.436371
# ..        ...                   ...     ...          ...
# 995  8.808934                  44.0       1     3.099150
# 996  8.808934                  65.0       1     3.505062
# 997  5.113546                  34.0       0    -3.362960
# 998  8.620000                  46.0       1     2.693239
# 999  5.113546                  10.0       1    -3.346724
#
# [1000 rows x 4 columns]

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(new_df_cap['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(new_df_cap['placement_exam_marks'])

plt.show()

# %% [markdown]
# # Outlier Detection using percentiles

# %%
df = pd.read_csv('weight-height.csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.shape
# Out:
# (10000, 3)

# %%
df.Height.describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.distplot(df.Height)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(df.Height)
# Out:
# <Axes: >

# %%
upper_limit = df['Height'].quantile(0.99)
upper_limit
# Out:
# 74.7857900583366

# %%
lower_limit = df['Height'].quantile(0.01)
lower_limit
# Out:
# 58.13441158671655

# %%
new_df = df[(df['Height'] <= 74.78) & (df['Height'] >= 58.13)]

# %%
new_df.Height.describe()
# Out:
# count    9799.000000
# mean       66.363507
# std         3.644267
# min        58.134496
# 25%        63.577147
# 50%        66.317899
# 75%        69.119859
# max        74.767447
# Name: Height, dtype: float64

# %%
sns.distplot(new_df.Height)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(new_df.Height)
# Out:
# <Axes: >

# %%
new_df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [9799 rows x 3 columns]

# %%
# Capping --> Winsorization

# %%
df['Height'] = np.where(df['Height'] >= upper_limit,
        upper_limit,
        np.where(df['Height'] <= lower_limit,
        lower_limit,
        df['Height']))

# %%
df.shape
# Out:
# (10000, 3)

# %%
df.Height.describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64

# %%
sns.distplot(df.Height)
# Out:
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(df.Height)
# Out:
# <Axes: >
